# %%
#I have multiple types of data files here in multiple formats. The data can be from:
#Strava
#Garmin
#TrainingPeaks
#AppleHealth (Questionable)

### Inputs:
#
#
#  Raw .csv files or .xml files 

### Outputs:
#
#
#  Curated csv of all the data to be used in EDA, modeling, etc

# %%
#Imports
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import json

# %%
#Let's inspect a .csv from garmin:
garmin = pd.read_csv('./data/raw/Garmin/BrianGetz_Activities.csv')

# %%
garmin.head()
# Out:
#   Activity Type                 Date  Favorite                       Title  \
# 0       Running  2021-02-01 16:57:42     False              Morton Running
# 1       Running  2021-01-30 13:31:55     False              Morton Running
# 2       Running  2021-01-29 15:54:41     False              Morton Running
# 3       Running  2021-01-28 09:43:06     False  Morton - Fartlek 1H1E x 15
# 4       Running  2021-01-26 16:33:47     False              Morton Running
#
#   Distance Calories      Time Avg HR Max HR Aerobic TE  ... Avg. Swolf  \
# 0     3.29      356  00:24:15    158    177        3.0  ...         --
# 1     1.88      214  00:20:02    130    144        1.7  ...         --
# 2     2.91      321  00:24:07    145    154        2.6  ...         --
# 3     9.00      999  01:08:56    162    177        4.6  ...         --
# 4     3.21      426  00:23:23     --     --         --  ...         --
#
#   Avg Stroke Rate Climb Time Bottom Time Min Temp Surface Interval  \
# 0              --      24:15        0:00      0.0             0:00
# 1              --      20:02        0:00      0.0             0:00
# 2              --      24:07        0:00      0.0             0:00
# 3              --    1:08:56        0:00      0.0             0:00
# 4              --      23:23        0:00      0.0             0:00
#
#    Decompression  Best Lap Time  Number of Laps Max Temp
# 0             No       02:11.51               4      0.0
# 1             No       09:22.95               2      0.0
# 2             No       07:27.09               3      0.0
# 3             No       01:00.00              44      0.0
# 4             No       01:28.40               4      0.0
#
# [5 rows x 40 columns]

# %%
garmin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 595 entries, 0 to 594
# Data columns (total 40 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Activity Type             595 non-null    object
#  1   Date                      595 non-null    object
#  2   Favorite                  595 non-null    bool
#  3   Title                     595 non-null    object
#  4   Distance                  595 non-null    object
#  5   Calories                  595 non-null    object
#  6   Time                      595 non-null    object
#  7   Avg HR                    595 non-null    object
#  8   Max HR                    595 non-null    object
#  9   Aerobic TE                595 non-null    object
#  10  Avg Run Cadence           595 non-null    object
#  11  Max Run Cadence           595 non-null    object
#  12  Avg Pace                  595 non-null    object
#  13  Best Pace                 595 non-null    object
#  14  Elev Gain                 595 non-null    object
#  15  Elev Loss                 595 non-null    object
#  16  Avg Stride Length         595 non-null    float64
#  17  Avg Vertical Ratio        595 non-null    float64
#  18  Avg Vertical Oscillation  595 non-null    float64
#  19  Avg Run Cadence.1         595 non-null    object
#  20  Max Run Cadence.1         595 non-null    object
#  21  Normalized Power® (NP®)   595 non-null    object
#  22  L/R Balance               595 non-null    object
#  23  Training Stress Score®    595 non-null    float64
#  24  Max Avg Power (20 min)    595 non-null    object
#  25  Avg Power                 595 non-null    object
#  26  Max Power                 595 non-null    object
#  27  Grit                      595 non-null    float64
#  28  Flow                      595 non-null    float64
#  29  Total Strokes             595 non-null    object
#  30  Avg. Swolf                595 non-null    object
#  31  Avg Stroke Rate           595 non-null    object
#  32  Climb Time                595 non-null    object
#  33  Bottom Time               595 non-null    object
#  34  Min Temp                  595 non-null    float64
#  35  Surface Interval          595 non-null    object
#  36  Decompression             595 non-null    object
#  37  Best Lap Time             595 non-null    object
#  38  Number of Laps            595 non-null    int64
#  39  Max Temp                  595 non-null    float64
# dtypes: bool(1), float64(8), int64(1), object(30)
# memory usage: 182.0+ KB

# %%
#Let's read in a strava file:

# %%
strava = pd.read_csv('./data/raw/Strava/claire_strava_activities.csv')

# %%
strava.head()
# Out:
#    Activity ID              Activity Date    Activity Name Activity Type  \
# 0    589807052   May 17, 2016, 3:27:58 PM     Morning Ride          Ride
# 1    590203279  May 27, 2016, 11:43:46 PM   Afternoon Ride          Ride
# 2    593258442   May 30, 2016, 5:47:48 PM  GG bridge to OB          Ride
# 3    594079803   May 31, 2016, 3:42:24 PM     Morning Ride          Ride
# 4    594639978    Jun 1, 2016, 1:30:33 AM     Evening Ride          Ride
#
#   Activity Description  Elapsed Time  Distance  Relative Effort Commute  \
# 0                  NaN          1791      8.34              NaN   False
# 1                  NaN          1742      8.32              NaN   False
# 2                  NaN          3183     12.06              NaN   False
# 3                  NaN          1820      8.39              NaN   False
# 4                  NaN          1907      8.66              NaN   False
#
#   Activity Gear  ... Precipitation Probability  Precipitation Type  \
# 0           NaN  ...                       NaN                 NaN
# 1           NaN  ...                       NaN                 NaN
# 2           NaN  ...                       NaN                 NaN
# 3           NaN  ...                       NaN                 NaN
# 4           NaN  ...                       NaN                 NaN
#
#    Cloud Cover  Weather Visibility  UV Index  Weather Ozone  \
# 0          NaN                 NaN       NaN            NaN
# 1          NaN                 NaN       NaN            NaN
# 2          NaN                 NaN       NaN            NaN
# 3          NaN                 NaN       NaN            NaN
# 4          NaN                 NaN       NaN            NaN
#
#    translation missing: en-US.lib.export.portability_exporter.activities.horton_values.jump_count  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    translation missing: en-US.lib.export.portability_exporter.activities.horton_values.total_grit  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_flow  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    translation missing: en-US.lib.export.portability_exporter.activities.horton_values.flagged
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 78 columns]

# %%
strava.columns
# Out:
# Index(['Activity ID', 'Activity Date', 'Activity Name', 'Activity Type',
#        'Activity Description', 'Elapsed Time', 'Distance', 'Relative Effort',
#        'Commute', 'Activity Gear', 'Filename', 'Athlete Weight', 'Bike Weight',
#        'Elapsed Time.1', 'Moving Time', 'Distance.1', 'Max Speed',
#        'Average Speed', 'Elevation Gain', 'Elevation Loss', 'Elevation Low',
#        'Elevation High', 'Max Grade', 'Average Grade',
#        'Average Positive Grade', 'Average Negative Grade', 'Max Cadence',
#        'Average Cadence', 'Max Heart Rate', 'Average Heart Rate', 'Max Watts',
#        'Average Watts', 'Calories', 'Max Temperature', 'Average Temperature',
#        'Relative Effort.1', 'Total Work', 'Number of Runs', 'Uphill Time',
#        'Downhill Time', 'Other Time', 'Perceived Exertion',
#        'translation missing: en-US.lib.export.portability_exporter.activities.horton_values.type',
#        'translation missing: en-US.lib.export.portability_exporter.activities.horton_values.start_time',
#        'Weighted Average Power', 'Power Count', 'Prefer Perceived Exertion',
#        'Perceived Relative Effort', 'Commute.1', 'Total Weight Lifted',
#        'From Upload', 'Grade Adjusted Distance', 'Weather Observation Time',
#        'Weather Condition', 'Weather Temperature', 'Apparent Temperature',
#        'Dewpoint', 'Humidity', 'Weather Pressure', 'Wind Speed', 'Wind Gust',
#        'Wind Bearing', 'Precipitation Intensity', 'Sunrise Time',
#        'Sunset Time', 'Moon Phase', 'Bike', 'Gear',
#        'Precipitation Probability', 'Precipitation Type', 'Cloud Cover',
#        'Weather Visibility', 'UV Index', 'Weather Ozone',
#        'translation missing: en-US.lib.export.portability_exporter.activities.horton_values.jump_count',
#        'translation missing: en-US.lib.export.portability_exporter.activities.horton_values.total_grit',
#        'translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_flow',
#        'translation missing: en-US.lib.export.portability_exporter.activities.horton_values.flagged'],
#       dtype='object')

# %%
strava.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 439 entries, 0 to 438
# Data columns (total 78 columns):
#  #   Column                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                          --------------  -----
#  0   Activity ID                                                                                     439 non-null    int64
#  1   Activity Date                                                                                   439 non-null    object
#  2   Activity Name                                                                                   439 non-null    object
#  3   Activity Type                                                                                   439 non-null    object
#  4   Activity Description                                                                            9 non-null      object
#  5   Elapsed Time                                                                                    439 non-null    int64
#  6   Distance                                                                                        439 non-null    float64
#  7   Relative Effort                                                                                 286 non-null    float64
#  8   Commute                                                                                         438 non-null    object
#  9   Activity Gear                                                                                   121 non-null    object
#  10  Filename                                                                                        436 non-null    object
#  11  Athlete Weight                                                                                  426 non-null    float64
#  12  Bike Weight                                                                                     0 non-null      float64
#  13  Elapsed Time.1                                                                                  428 non-null    float64
#  14  Moving Time                                                                                     439 non-null    float64
#  15  Distance.1                                                                                      429 non-null    float64
#  16  Max Speed                                                                                       436 non-null    float64
#  17  Average Speed                                                                                   40 non-null     float64
#  18  Elevation Gain                                                                                  426 non-null    float64
#  19  Elevation Loss                                                                                  22 non-null     float64
#  20  Elevation Low                                                                                   420 non-null    float64
#  21  Elevation High                                                                                  420 non-null    float64
#  22  Max Grade                                                                                       436 non-null    float64
#  23  Average Grade                                                                                   439 non-null    float64
#  24  Average Positive Grade                                                                          0 non-null      float64
#  25  Average Negative Grade                                                                          0 non-null      float64
#  26  Max Cadence                                                                                     0 non-null      float64
#  27  Average Cadence                                                                                 0 non-null      float64
#  28  Max Heart Rate                                                                                  285 non-null    float64
#  29  Average Heart Rate                                                                              228 non-null    float64
#  30  Max Watts                                                                                       0 non-null      float64
#  31  Average Watts                                                                                   67 non-null     float64
#  32  Calories                                                                                        122 non-null    float64
#  33  Max Temperature                                                                                 0 non-null      float64
#  34  Average Temperature                                                                             0 non-null      float64
#  35  Relative Effort.1                                                                               286 non-null    float64
#  36  Total Work                                                                                      0 non-null      float64
#  37  Number of Runs                                                                                  0 non-null      float64
#  38  Uphill Time                                                                                     0 non-null      float64
#  39  Downhill Time                                                                                   0 non-null      float64
#  40  Other Time                                                                                      0 non-null      float64
#  41  Perceived Exertion                                                                              14 non-null     float64
#  42  translation missing: en-US.lib.export.portability_exporter.activities.horton_values.type        0 non-null      float64
#  43  translation missing: en-US.lib.export.portability_exporter.activities.horton_values.start_time  0 non-null      float64
#  44  Weighted Average Power                                                                          0 non-null      float64
#  45  Power Count                                                                                     0 non-null      float64
#  46  Prefer Perceived Exertion                                                                       26 non-null     float64
#  47  Perceived Relative Effort                                                                       14 non-null     float64
#  48  Commute.1                                                                                       404 non-null    float64
#  49  Total Weight Lifted                                                                             0 non-null      float64
#  50  From Upload                                                                                     31 non-null     float64
#  51  Grade Adjusted Distance                                                                         31 non-null     float64
#  52  Weather Observation Time                                                                        21 non-null     float64
#  53  Weather Condition                                                                               21 non-null     float64
#  54  Weather Temperature                                                                             21 non-null     float64
#  55  Apparent Temperature                                                                            21 non-null     float64
#  56  Dewpoint                                                                                        21 non-null     float64
#  57  Humidity                                                                                        21 non-null     float64
#  58  Weather Pressure                                                                                21 non-null     float64
#  59  Wind Speed                                                                                      21 non-null     float64
#  60  Wind Gust                                                                                       21 non-null     float64
#  61  Wind Bearing                                                                                    21 non-null     float64
#  62  Precipitation Intensity                                                                         21 non-null     float64
#  63  Sunrise Time                                                                                    21 non-null     float64
#  64  Sunset Time                                                                                     21 non-null     float64
#  65  Moon Phase                                                                                      21 non-null     float64
#  66  Bike                                                                                            0 non-null      float64
#  67  Gear                                                                                            256 non-null    float64
#  68  Precipitation Probability                                                                       20 non-null     float64
#  69  Precipitation Type                                                                              0 non-null      float64
#  70  Cloud Cover                                                                                     20 non-null     float64
#  71  Weather Visibility                                                                              20 non-null     float64
#  72  UV Index                                                                                        20 non-null     float64
#  73  Weather Ozone                                                                                   20 non-null     float64
#  74  translation missing: en-US.lib.export.portability_exporter.activities.horton_values.jump_count  0 non-null      float64
#  75  translation missing: en-US.lib.export.portability_exporter.activities.horton_values.total_grit  0 non-null      float64
#  76  translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_flow    0 non-null      float64
#  77  translation missing: en-US.lib.export.portability_exporter.activities.horton_values.flagged     0 non-null      float64
# dtypes: float64(69), int64(2), object(7)
# memory usage: 267.6+ KB

# %%
#Ok what about a TrainingPeaks file?

# %%
tp = pd.read_csv('./data/raw/TrainingPeaks/workouts.csv')

# %%
tp.head()
# Out:
#   Title WorkoutType WorkoutDescription  PlannedDuration  \
# 0   NaN        Bike                NaN              NaN
# 1   NaN         Run                NaN              NaN
# 2   NaN         Run                NaN              NaN
# 3   NaN         Run                NaN              NaN
# 4   NaN        Bike                NaN              NaN
#
#    PlannedDistanceInMeters  WorkoutDay CoachComments  DistanceInMeters  \
# 0                      NaN  2016-12-01           NaN        178.979996
# 1                      NaN  2016-12-02           NaN       7596.680176
# 2                      NaN  2016-12-03           NaN       8260.419922
# 3                      NaN  2016-12-03           NaN        498.399994
# 4                      NaN  2016-12-04           NaN        224.899994
#
#    PowerAverage  PowerMax  ...  PWRZone3Minutes PWRZone4Minutes  \
# 0         155.0     355.0  ...             12.0             1.0
# 1           NaN       NaN  ...              NaN             NaN
# 2           NaN       NaN  ...              NaN             NaN
# 3           NaN       NaN  ...              NaN             NaN
# 4         132.0     298.0  ...              4.0             1.0
#
#    PWRZone5Minutes  PWRZone6Minutes  PWRZone7Minutes  PWRZone8Minutes  \
# 0              0.0              0.0              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              0.0              0.0              NaN              NaN
#
#    PWRZone9Minutes  PWRZone10Minutes  Rpe  Feeling
# 0              NaN               NaN  NaN      NaN
# 1              NaN               NaN  NaN      NaN
# 2              NaN               NaN  NaN      NaN
# 3              NaN               NaN  NaN      NaN
# 4              NaN               NaN  NaN      NaN
#
# [5 rows x 45 columns]

# %%
tp.columns
# Out:
# Index(['Title', 'WorkoutType', 'WorkoutDescription', 'PlannedDuration',
#        'PlannedDistanceInMeters', 'WorkoutDay', 'CoachComments',
#        'DistanceInMeters', 'PowerAverage', 'PowerMax', 'Energy',
#        'AthleteComments', 'TimeTotalInHours', 'VelocityAverage', 'VelocityMax',
#        'CadenceAverage', 'CadenceMax', 'HeartRateAverage', 'HeartRateMax',
#        'TorqueAverage', 'TorqueMax', 'IF', 'TSS', 'HRZone1Minutes',
#        'HRZone2Minutes', 'HRZone3Minutes', 'HRZone4Minutes', 'HRZone5Minutes',
#        'HRZone6Minutes', 'HRZone7Minutes', 'HRZone8Minutes', 'HRZone9Minutes',
#        'HRZone10Minutes', 'PWRZone1Minutes', 'PWRZone2Minutes',
#        'PWRZone3Minutes', 'PWRZone4Minutes', 'PWRZone5Minutes',
#        'PWRZone6Minutes', 'PWRZone7Minutes', 'PWRZone8Minutes',
#        'PWRZone9Minutes', 'PWRZone10Minutes', 'Rpe', 'Feeling'],
#       dtype='object')

# %%
tp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 658 entries, 0 to 657
# Data columns (total 45 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Title                    339 non-null    object
#  1   WorkoutType              658 non-null    object
#  2   WorkoutDescription       245 non-null    object
#  3   PlannedDuration          218 non-null    float64
#  4   PlannedDistanceInMeters  40 non-null     float64
#  5   WorkoutDay               658 non-null    object
#  6   CoachComments            19 non-null     object
#  7   DistanceInMeters         489 non-null    float64
#  8   PowerAverage             125 non-null    float64
#  9   PowerMax                 125 non-null    float64
#  10  Energy                   125 non-null    float64
#  11  AthleteComments          21 non-null     object
#  12  TimeTotalInHours         488 non-null    float64
#  13  VelocityAverage          483 non-null    float64
#  14  VelocityMax              0 non-null      float64
#  15  CadenceAverage           395 non-null    float64
#  16  CadenceMax               0 non-null      float64
#  17  HeartRateAverage         391 non-null    float64
#  18  HeartRateMax             391 non-null    float64
#  19  TorqueAverage            0 non-null      float64
#  20  TorqueMax                0 non-null      float64
#  21  IF                       463 non-null    float64
#  22  TSS                      463 non-null    float64
#  23  HRZone1Minutes           362 non-null    float64
#  24  HRZone2Minutes           362 non-null    float64
#  25  HRZone3Minutes           362 non-null    float64
#  26  HRZone4Minutes           362 non-null    float64
#  27  HRZone5Minutes           328 non-null    float64
#  28  HRZone6Minutes           0 non-null      float64
#  29  HRZone7Minutes           0 non-null      float64
#  30  HRZone8Minutes           0 non-null      float64
#  31  HRZone9Minutes           0 non-null      float64
#  32  HRZone10Minutes          0 non-null      float64
#  33  PWRZone1Minutes          125 non-null    float64
#  34  PWRZone2Minutes          125 non-null    float64
#  35  PWRZone3Minutes          125 non-null    float64
#  36  PWRZone4Minutes          125 non-null    float64
#  37  PWRZone5Minutes          125 non-null    float64
#  38  PWRZone6Minutes          125 non-null    float64
#  39  PWRZone7Minutes          0 non-null      float64
#  40  PWRZone8Minutes          0 non-null      float64
#  41  PWRZone9Minutes          0 non-null      float64
#  42  PWRZone10Minutes         0 non-null      float64
#  43  Rpe                      0 non-null      float64
#  44  Feeling                  0 non-null      float64
# dtypes: float64(39), object(6)
# memory usage: 231.5+ KB

# %%
tp.dropna(subset=['TimeTotalInHours']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 488 entries, 0 to 657
# Data columns (total 45 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Title                    170 non-null    object
#  1   WorkoutType              488 non-null    object
#  2   WorkoutDescription       124 non-null    object
#  3   PlannedDuration          128 non-null    float64
#  4   PlannedDistanceInMeters  18 non-null     float64
#  5   WorkoutDay               488 non-null    object
#  6   CoachComments            15 non-null     object
#  7   DistanceInMeters         483 non-null    float64
#  8   PowerAverage             125 non-null    float64
#  9   PowerMax                 125 non-null    float64
#  10  Energy                   125 non-null    float64
#  11  AthleteComments          17 non-null     object
#  12  TimeTotalInHours         488 non-null    float64
#  13  VelocityAverage          483 non-null    float64
#  14  VelocityMax              0 non-null      float64
#  15  CadenceAverage           395 non-null    float64
#  16  CadenceMax               0 non-null      float64
#  17  HeartRateAverage         391 non-null    float64
#  18  HeartRateMax             391 non-null    float64
#  19  TorqueAverage            0 non-null      float64
#  20  TorqueMax                0 non-null      float64
#  21  IF                       463 non-null    float64
#  22  TSS                      463 non-null    float64
#  23  HRZone1Minutes           362 non-null    float64
#  24  HRZone2Minutes           362 non-null    float64
#  25  HRZone3Minutes           362 non-null    float64
#  26  HRZone4Minutes           362 non-null    float64
#  27  HRZone5Minutes           328 non-null    float64
#  28  HRZone6Minutes           0 non-null      float64
#  29  HRZone7Minutes           0 non-null      float64
#  30  HRZone8Minutes           0 non-null      float64
#  31  HRZone9Minutes           0 non-null      float64
#  32  HRZone10Minutes          0 non-null      float64
#  33  PWRZone1Minutes          125 non-null    float64
#  34  PWRZone2Minutes          125 non-null    float64
#  35  PWRZone3Minutes          125 non-null    float64
#  36  PWRZone4Minutes          125 non-null    float64
#  37  PWRZone5Minutes          125 non-null    float64
#  38  PWRZone6Minutes          125 non-null    float64
#  39  PWRZone7Minutes          0 non-null      float64
#  40  PWRZone8Minutes          0 non-null      float64
#  41  PWRZone9Minutes          0 non-null      float64
#  42  PWRZone10Minutes         0 non-null      float64
#  43  Rpe                      0 non-null      float64
#  44  Feeling                  0 non-null      float64
# dtypes: float64(39), object(6)
# memory usage: 175.4+ KB

# %%
#Maybe a quick graph to see what I can see?
garmin_run = garmin[garmin['Activity Type'] == 'Running']

# %%
len(garmin_run)
# Out:
# 513

# %%
garmin_run['Distance'] = pd.to_numeric(garmin_run['Distance'])
# Out:
# <ipython-input-17-e3c8ac8722f6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   garmin_run['Distance'] = pd.to_numeric(garmin_run['Distance'])

# %%
garmin_run[garmin_run['Distance'] > 12.9]
# Out:
#     Activity Type                 Date  Favorite                      Title  \
# 244       Running  2020-02-06 09:22:40     False  Steamboat Springs Running
# 353       Running  2019-07-13 06:03:14     False              Aspen Running
# 360       Running  2019-07-05 05:40:16     False        East Moline Running
# 376       Running  2019-06-14 05:30:57     False          Lafayette Running
# 382       Running  2019-06-11 14:50:53     False          Lafayette Running
# 387       Running  2019-06-07 07:01:32     False         Broomfield Running
# 392       Running  2019-06-04 08:15:05     False          Lafayette Running
# 395       Running  2019-05-31 09:08:21     False          Lafayette Running
# 403       Running  2019-05-24 13:13:10     False          Lafayette Running
# 410       Running  2019-05-16 06:02:40     False         Louisville Running
# 415       Running  2019-05-10 07:20:55     False     Douglas County Running
# 418       Running  2019-05-06 09:39:42     False  Lafayette - 5 x 1.5 miles
# 426       Running  2019-04-26 06:10:53     False          Lafayette Running
# 434       Running  2019-04-19 14:17:59     False          Lafayette Running
# 450       Running  2019-04-06 07:01:41     False          Lafayette Running
# 494       Running  2019-02-10 08:43:48     False  Steamboat Springs Running
# 495       Running  2019-02-09 13:22:46     False  Steamboat Springs Running
# 498       Running  2019-02-02 10:33:50     False       Eagle County Running
# 570       Running  2018-09-01 08:38:51     False          Lafayette Running
#
#      Distance Calories      Time Avg HR Max HR Aerobic TE  ... Avg. Swolf  \
# 244     18.03    1,788  02:23:36     --     --         --  ...         --
# 353     26.03    3,460  02:59:55     --     --         --  ...         --
# 360     14.01    1,618  02:02:45    146    181        3.6  ...         --
# 376     20.02    2,372  02:48:41    153    175        3.8  ...         --
# 382     13.33    1,469  01:36:54    160    183        3.9  ...         --
# 387     18.01    2,234  02:26:30    162    187        4.5  ...         --
# 392     14.09    1,681  01:46:07    164    184        4.8  ...         --
# 395     14.77    1,967  01:56:29     --     --         --  ...         --
# 403     15.01    1,777  01:51:22    165    184        5.0  ...         --
# 410     18.01    2,059  02:18:10    156    181        4.9  ...         --
# 415     16.01    1,772  02:11:00    152    179        3.5  ...         --
# 418     14.00    1,681  01:45:34    160    182        4.5  ...         --
# 426     15.01    1,433  02:11:32    141    176        2.8  ...         --
# 434     13.23    1,698  01:53:54    159    181        4.5  ...         --
# 450     15.03    1,576  02:09:52    148    171        3.1  ...         --
# 494     26.90    2,428  02:51:48     --     --         --  ...         --
# 495     16.30    1,427  01:45:40     --     --         --  ...         --
# 498     51.99    4,622  05:40:32     --     --         --  ...         --
# 570     13.32    1,565  01:48:11    152    176        4.6  ...         --
#
#     Avg Stroke Rate Climb Time Bottom Time Min Temp Surface Interval  \
# 244              --    2:23:36        0:00      0.0             0:00
# 353              --    2:59:55        0:00      0.0             0:00
# 360              --    2:02:45        0:00      0.0             0:00
# 376              --    2:48:41        0:00      0.0             0:00
# 382              --    1:36:54        0:00      0.0             0:00
# 387              --    2:26:30        0:00      0.0             0:00
# 392              --    1:46:07        0:00      0.0             0:00
# 395              --    1:56:29        0:00      0.0             0:00
# 403              --    1:51:22        0:00      0.0             0:00
# 410              --    2:18:10        0:00      0.0             0:00
# 415              --    2:11:00        0:00      0.0             0:00
# 418              --    1:45:34        0:00      0.0             0:00
# 426              --    2:11:32        0:00      0.0             0:00
# 434              --    1:53:54        0:00      0.0             0:00
# 450              --    2:09:52        0:00      0.0             0:00
# 494              --    2:51:48        0:00      0.0             0:00
# 495              --    1:45:40        0:00      0.0             0:00
# 498              --    5:40:32        0:00      0.0             0:00
# 570              --    1:48:11        0:00      0.0             0:00
#
#      Decompression  Best Lap Time  Number of Laps Max Temp
# 244             No       00:50.52              19      0.0
# 353             No       00:08.56              27      0.0
# 360             No       00:06.64              15      0.0
# 376             No       00:10.64              21      0.0
# 382             No       02:53.24              14      0.0
# 387             No       00:04.09              19      0.0
# 392             No       00:45.23              15      0.0
# 395             No       06:33.54              15      0.0
# 403             No       00:04.60              16      0.0
# 410             No       00:06.74              19      0.0
# 415             No       00:03.31              17      0.0
# 418             No       03:14.71              19      0.0
# 426             No       00:05.45              16      0.0
# 434             No       02:01.14              14      0.0
# 450             No       00:14.32              16      0.0
# 494             No       02:25.40              27      0.0
# 495             No       02:28.99              17      0.0
# 498             No       00:00.69              54      0.0
# 570             No       00:00.00              14      0.0
#
# [19 rows x 40 columns]

# %%
garmin_run['Date'] = pd.to_datetime(garmin_run['Date'])
# Out:
# <ipython-input-71-8ae6960d3988>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   garmin_run['Date'] = pd.to_datetime(garmin_run['Date'])

# %%
garmin_run.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 513 entries, 0 to 594
# Data columns (total 40 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Activity Type             513 non-null    object
#  1   Date                      513 non-null    datetime64[ns]
#  2   Favorite                  513 non-null    bool
#  3   Title                     513 non-null    object
#  4   Distance                  513 non-null    float64
#  5   Calories                  513 non-null    object
#  6   Time                      513 non-null    object
#  7   Avg HR                    513 non-null    object
#  8   Max HR                    513 non-null    object
#  9   Aerobic TE                513 non-null    object
#  10  Avg Run Cadence           513 non-null    object
#  11  Max Run Cadence           513 non-null    object
#  12  Avg Pace                  513 non-null    object
#  13  Best Pace                 513 non-null    object
#  14  Elev Gain                 513 non-null    object
#  15  Elev Loss                 513 non-null    object
#  16  Avg Stride Length         513 non-null    float64
#  17  Avg Vertical Ratio        513 non-null    float64
#  18  Avg Vertical Oscillation  513 non-null    float64
#  19  Avg Run Cadence.1         513 non-null    object
#  20  Max Run Cadence.1         513 non-null    object
#  21  Normalized Power® (NP®)   513 non-null    object
#  22  L/R Balance               513 non-null    object
#  23  Training Stress Score®    513 non-null    float64
#  24  Max Avg Power (20 min)    513 non-null    object
#  25  Avg Power                 513 non-null    object
#  26  Max Power                 513 non-null    object
#  27  Grit                      513 non-null    float64
#  28  Flow                      513 non-null    float64
#  29  Total Strokes             513 non-null    object
#  30  Avg. Swolf                513 non-null    object
#  31  Avg Stroke Rate           513 non-null    object
#  32  Climb Time                513 non-null    object
#  33  Bottom Time               513 non-null    object
#  34  Min Temp                  513 non-null    float64
#  35  Surface Interval          513 non-null    object
#  36  Decompression             513 non-null    object
#  37  Best Lap Time             513 non-null    object
#  38  Number of Laps            513 non-null    int64
#  39  Max Temp                  513 non-null    float64
# dtypes: bool(1), datetime64[ns](1), float64(9), int64(1), object(28)
# memory usage: 160.8+ KB

# %%
obj_to_num_cols = ['Calories', 'Avg HR', 'Max HR', 'Aerobic TE', 'Avg Run Cadence', 'Max Run Cadence', 'Elev Gain', 'Elev Loss', 'Avg Run Cadence.1', 'Avg Power', 'Max Power']

# %%
#Found out this is very important in garmin files:
garmin_run.replace('--', 0, inplace = True)
# Out:
# /Users/Keith/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py:4521: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
for col in obj_to_num_cols:
    try:
        garmin_run[col] = pd.to_numeric(garmin_run[col])
    except:
        try:
            garmin_run[col] = pd.to_numeric(garmin_run[col].str.extract(r'd+'))
        except:
            pass
# Out:
# <ipython-input-21-9b4225c12bc0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   garmin_run[col] = pd.to_numeric(garmin_run[col])

# %%
garmin_run['Max HR'].unique()
# Out:
# array([177, 144, 154,   0, 166, 182, 147, 164, 172, 178, 183, 163, 160,
#        168, 152, 162, 176, 155, 150, 175, 174, 171, 185, 165, 170, 157,
#        180, 169, 167, 181, 153, 141, 146, 161, 186, 143, 148, 159, 184,
#        193, 173, 189, 187, 156, 145, 179, 158, 149, 190, 191, 151, 106])

# %%
garmin_run['Avg HR'].unique()
# Out:
# array([158, 130, 145, 162,   0, 154, 166, 133, 149, 155, 160, 148, 152,
#        164, 137, 135, 144, 150, 136, 138, 153, 175, 146, 134, 143, 163,
#        139, 161, 156, 151, 165, 141, 159, 140, 131, 142, 147, 168, 132,
#        169, 181, 179,  92,  96])

# %%
garmin_run['Avg HR']/garmin_run['Max HR']
# Out:
# 0      0.892655
# 1      0.902778
# 2      0.941558
# 3      0.915254
# 4           NaN
#          ...
# 587    0.815029
# 590    0.876404
# 591    0.866667
# 592    0.905660
# 594    0.806630
# Length: 513, dtype: float64

# %% [markdown]
# ## Garmin processing step that is very important below:

# %%
garmin_run.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 513 entries, 0 to 594
# Data columns (total 40 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Activity Type             513 non-null    object
#  1   Date                      513 non-null    datetime64[ns]
#  2   Favorite                  513 non-null    bool
#  3   Title                     513 non-null    object
#  4   Distance                  513 non-null    object
#  5   Calories                  513 non-null    object
#  6   Time                      513 non-null    object
#  7   Avg HR                    513 non-null    int64
#  8   Max HR                    513 non-null    int64
#  9   Aerobic TE                513 non-null    float64
#  10  Avg Run Cadence           513 non-null    int64
#  11  Max Run Cadence           513 non-null    int64
#  12  Avg Pace                  513 non-null    object
#  13  Best Pace                 513 non-null    object
#  14  Elev Gain                 513 non-null    object
#  15  Elev Loss                 513 non-null    object
#  16  Avg Stride Length         513 non-null    float64
#  17  Avg Vertical Ratio        513 non-null    float64
#  18  Avg Vertical Oscillation  513 non-null    float64
#  19  Avg Run Cadence.1         513 non-null    int64
#  20  Max Run Cadence.1         513 non-null    int64
#  21  Normalized Power® (NP®)   513 non-null    int64
#  22  L/R Balance               513 non-null    int64
#  23  Training Stress Score®    513 non-null    float64
#  24  Max Avg Power (20 min)    513 non-null    int64
#  25  Avg Power                 513 non-null    int64
#  26  Max Power                 513 non-null    int64
#  27  Grit                      513 non-null    float64
#  28  Flow                      513 non-null    float64
#  29  Total Strokes             513 non-null    int64
#  30  Avg. Swolf                513 non-null    int64
#  31  Avg Stroke Rate           513 non-null    int64
#  32  Climb Time                513 non-null    object
#  33  Bottom Time               513 non-null    object
#  34  Min Temp                  513 non-null    float64
#  35  Surface Interval          513 non-null    object
#  36  Decompression             513 non-null    object
#  37  Best Lap Time             513 non-null    object
#  38  Number of Laps            513 non-null    int64
#  39  Max Temp                  513 non-null    float64
# dtypes: bool(1), datetime64[ns](1), float64(9), int64(15), object(14)
# memory usage: 160.8+ KB

# %%
#conda env list

# %%
#conda env

# %%
#pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (20, 12))
plt.plot(garmin_run[garmin_run['Distance'] < 26.5]['Date'], garmin_run[garmin_run['Distance'] < 26.5]['Distance'])
plt.xlabel('Run')
plt.ylabel('Distance (Miles)')
plt.title('Last 100 Runs, Distance')
# Out:
# Text(0.5, 1.0, 'Last 100 Runs, Distance')

# %%
garmin_run.set_index(garmin_run['Date'], inplace = True)

# %%
len(garmin_run['2019':])
# Out:
# 285

# %%
pace_cols = ['Avg Pace', 'Best Pace']

# %%
pd.to_timedelta(garmin_run['Avg Pace'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/tslibs/timedeltas.pyx in pandas._libs.tslibs.timedeltas.array_to_timedelta64()
#
# pandas/_libs/tslibs/timedeltas.pyx in pandas._libs.tslibs.timedeltas.parse_timedelta_string()
#
# ValueError: expected hh:mm:ss format
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-2b2c645a7347> in <module>
# ----> 1 pd.to_timedelta(garmin_run['Avg Pace'])
#
# ~/miniconda3/envs/sql/lib/python3.8/site-packages/pandas/core/tools/timedeltas.py in to_timedelta(arg, unit, errors)
#     112         return arg
#     113     elif isinstance(arg, ABCSeries):
# --> 114         values = _convert_listlike(arg._values, unit=unit, errors=errors)
#     115         return arg._constructor(values, index=arg.index, name=arg.name)
#     116     elif isinstance(arg, ABCIndexClass):
#
# ~/miniconda3/envs/sql/lib/python3.8/site-packages/pandas/core/tools/timedeltas.py in _convert_listlike(arg, unit, errors, name)
#     159
#     160     try:
# --> 161         value = sequence_to_td64ns(arg, unit=unit, errors=errors, copy=False)[0]
#     162     except ValueError:
#     163         if errors == "ignore":
#
# ~/miniconda3/envs/sql/lib/python3.8/site-packages/pandas/core/arrays/timedeltas.py in sequence_to_td64ns(data, copy, unit, errors)
#     955     if is_object_dtype(data.dtype) or is_string_dtype(data.dtype):
#     956         # no need to make a copy, need to convert if string-dtyped
# --> 957         data = objects_to_td64ns(data, unit=unit, errors=errors)
#     958         copy = False
#     959
#
# ~/miniconda3/envs/sql/lib/python3.8/site-packages/pandas/core/arrays/timedeltas.py in objects_to_td64ns(data, unit, errors)
#    1065     values = np.array(data, dtype=np.object_, copy=False)
#    1066
# -> 1067     result = array_to_timedelta64(values, unit=unit, errors=errors)
#    1068     return result.view("timedelta64[ns]")
#    1069
#
# pandas/_libs/tslibs/timedeltas.pyx in pandas._libs.tslibs.timedeltas.array_to_timedelta64()
#
# pandas/_libs/tslibs/timedeltas.pyx in pandas._libs.tslibs.timedeltas.array_to_timedelta64()
#
# pandas/_libs/tslibs/timedeltas.pyx in pandas._libs.tslibs.timedeltas.convert_to_timedelta64()
#
# pandas/_libs/tslibs/timedeltas.pyx in pandas._libs.tslibs.timedeltas.parse_timedelta_string()
#
# ValueError: expected hh:mm:ss format

# %%
time = pd.to_timedelta('00:'+garmin_run['Avg Pace'][0])

# %%
'12:02:38' + time
# Out:
# Timedelta('0 days 12:10:00')

# %% [markdown]
# ## Converting Paces to timedeltas for comparison:

# %%
for col in pace_cols:
    #print(col)
    for i in range(len(garmin_run[col])):
        try:
            #print(i)
            #print(garmin_run[col][i])
            garmin_run[col][i] = pd.to_timedelta('00:'+garmin_run[col][i])
        except:
            if garmin_run[col][i]==0:
                garmin_run[col][i] = pd.to_timedelta('00:00:00')
# Out:
# <ipython-input-87-efbd2b2a80cb>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   garmin_run[col][i] = pd.to_timedelta('00:00:00')
# /Users/Keith/miniconda3/envs/sql/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3427: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
((pd.DataFrame(garmin_run['Best Pace']))==str).sum()
# Out:
# Best Pace    0
# dtype: int64

# %%
garmin_run.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 513 entries, 2021-02-01 16:57:42 to 2018-08-07 10:12:37
# Data columns (total 40 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Activity Type             513 non-null    object
#  1   Date                      513 non-null    datetime64[ns]
#  2   Favorite                  513 non-null    bool
#  3   Title                     513 non-null    object
#  4   Distance                  513 non-null    object
#  5   Calories                  513 non-null    object
#  6   Time                      513 non-null    object
#  7   Avg HR                    513 non-null    int64
#  8   Max HR                    513 non-null    int64
#  9   Aerobic TE                513 non-null    float64
#  10  Avg Run Cadence           513 non-null    int64
#  11  Max Run Cadence           513 non-null    int64
#  12  Avg Pace                  513 non-null    object
#  13  Best Pace                 513 non-null    object
#  14  Elev Gain                 513 non-null    object
#  15  Elev Loss                 513 non-null    object
#  16  Avg Stride Length         513 non-null    float64
#  17  Avg Vertical Ratio        513 non-null    float64
#  18  Avg Vertical Oscillation  513 non-null    float64
#  19  Avg Run Cadence.1         513 non-null    int64
#  20  Max Run Cadence.1         513 non-null    int64
#  21  Normalized Power® (NP®)   513 non-null    int64
#  22  L/R Balance               513 non-null    int64
#  23  Training Stress Score®    513 non-null    float64
#  24  Max Avg Power (20 min)    513 non-null    int64
#  25  Avg Power                 513 non-null    int64
#  26  Max Power                 513 non-null    int64
#  27  Grit                      513 non-null    float64
#  28  Flow                      513 non-null    float64
#  29  Total Strokes             513 non-null    int64
#  30  Avg. Swolf                513 non-null    int64
#  31  Avg Stroke Rate           513 non-null    int64
#  32  Climb Time                513 non-null    object
#  33  Bottom Time               513 non-null    object
#  34  Min Temp                  513 non-null    float64
#  35  Surface Interval          513 non-null    object
#  36  Decompression             513 non-null    object
#  37  Best Lap Time             513 non-null    object
#  38  Number of Laps            513 non-null    int64
#  39  Max Temp                  513 non-null    float64
# dtypes: bool(1), datetime64[ns](1), float64(9), int64(15), object(14)
# memory usage: 160.8+ KB

# %%
garmin_run['Avg Pace'][107]
# Out:
# Timedelta('0 days 00:00:00')

# %%
r_logo = garmin_run.columns[23][-1]

# %%
garmin_run.columns.str.replace(r_logo, '')
# Out:
# Index(['Activity Type', 'Date', 'Favorite', 'Title', 'Distance', 'Calories',
#        'Time', 'Avg HR', 'Max HR', 'Aerobic TE', 'Avg Run Cadence',
#        'Max Run Cadence', 'Avg Pace', 'Best Pace', 'Elev Gain', 'Elev Loss',
#        'Avg Stride Length', 'Avg Vertical Ratio', 'Avg Vertical Oscillation',
#        'Avg Run Cadence.1', 'Max Run Cadence.1', 'Normalized Power (NP)',
#        'L/R Balance', 'Training Stress Score', 'Max Avg Power (20 min)',
#        'Avg Power', 'Max Power', 'Grit', 'Flow', 'Total Strokes', 'Avg. Swolf',
#        'Avg Stroke Rate', 'Climb Time', 'Bottom Time', 'Min Temp',
#        'Surface Interval', 'Decompression', 'Best Lap Time', 'Number of Laps',
#        'Max Temp'],
#       dtype='object')

# %%
garmin_run.columns.str.replace('/', '').str.lower().str.replace('.', '_').str.replace(' ', '_').str.replace('(', '').str.replace(')', '').str.replace(r_logo, '')
# Out:
# <ipython-input-112-6cdca69e2767>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   garmin_run.columns.str.replace('/', '').str.lower().str.replace('.', '_').str.replace(' ', '_').str.replace('(', '').str.replace(')', '').str.replace(r_logo, '')
# Index(['activity_type', 'date', 'favorite', 'title', 'distance', 'calories',
#        'time', 'avg_hr', 'max_hr', 'aerobic_te', 'avg_run_cadence',
#        'max_run_cadence', 'avg_pace', 'best_pace', 'elev_gain', 'elev_loss',
#        'avg_stride_length', 'avg_vertical_ratio', 'avg_vertical_oscillation',
#        'avg_run_cadence_1', 'max_run_cadence_1', 'normalized_power_np',
#        'lr_balance', 'training_stress_score', 'max_avg_power_20_min',
#        'avg_power', 'max_power', 'grit', 'flow', 'total_strokes', 'avg__swolf',
#        'avg_stroke_rate', 'climb_time', 'bottom_time', 'min_temp',
#        'surface_interval', 'decompression', 'best_lap_time', 'number_of_laps',
#        'max_temp'],
#       dtype='object')

# %%
#Ok let's make a function for garmin importing to get the data ready for final importation:
#We will need a 'is_race' column, and an 'athlete_id' column to allow us to group like training together, and determine which rows are our target values:
#Also might want a 'type = 'Garmin'

# %%
def import_transf_garmin(filepath, athlete_id, race_dates): #Filepath is the csv filepath, athlete_id is a counter variable, race_dates is the list of race dates
    
    #Read in the dataframe:
    df = pd.read_csv(filepath)
    #Found out this is very important in garmin files:
    df.replace('--', 0, inplace = True)
    
    #Create athlete_id, file type and race category column:
    df['athlete_id'] = athlete_id
    df['filetype'] = 'garmin'
    df['is_race'] = 0
    
    
    #Define the columns to have their data types transformed:
    obj_to_num_cols = ['Calories', 'Avg HR', 'Max HR', 'Aerobic TE', 'Avg Run Cadence', 'Max Run Cadence', 'Elev Gain', 'Elev Loss', 'Avg Run Cadence.1', 'Avg Power', 'Max Power']
    pace_cols = ['Avg Pace', 'Best Pace']
    
    #Convert the numeric columns:
    for col in obj_to_num_cols:
        try:
            df[col] = pd.to_numeric(df[col])
        except:
            try:
                df[col] = pd.to_numeric(df[col].str.extract(r'd+'))
            except:
                pass
    
    #Convert the pace columns:
    for col in pace_cols:
        for i in range(len(df[col])):
            try:
                df[col][i] = pd.to_timedelta('00:'+df[col][i])
            except:
                #print(f'col={col}')
                #print(f'i= {i}')
                #print(f'df[col][i] = {df[col][i]}')
                if df[col][i]==0:
                    df[col][i] = pd.to_timedelta('00:00:00')
                else:
                    pass
                pass
    
    #Clean up the column names:
    #This is to remove the (R) logo so it doesn't cause any issues later:
    r_logo = df.columns[df.columns.str.contains('Training Stress')][0][-1]
    #Clean up the column names:
    df.columns = df.columns.str.replace('/', '').str.lower().str.replace('.', '_').str.replace(' ', '_').str.replace('(', '').str.replace(')', '').str.replace(r_logo, '')
    df.set_index(df['date'], inplace = True)
    df.index = pd.to_datetime(df.index)
    ###Write a function to change the race dates in race_dates to a '1'
    
    #Write out the file to the data folder:
    df.to_csv(f'./data/clean/garmin_clean/clean_{athlete_id}.csv')

# %%
import_transf_garmin('./data/raw/Garmin/Activities_Anel_Akiyanova.csv', 2, [])
# Out:
# col=Avg Pace
# i= 9
# df[col][i] = 0
# <ipython-input-57-d5dde7da7043>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col][i] = pd.to_timedelta('00:'+df[col][i])
# <ipython-input-57-d5dde7da7043>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col][i] = pd.to_timedelta('00:00:00')
# <ipython-input-57-d5dde7da7043>:47: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('/', '').str.lower().str.replace('.', '_').str.replace(' ', '_').str.replace('(', '').str.replace(')', '').str.replace(r_logo, '')

# %%
test = pd.read_csv('./data/clean/garmin_clean/clean_2.csv', index_col='date').drop('date.1', axis =1)

# %%
test.head()
# Out:
#                     activity_type  favorite                 title  distance  \
# date
# 2020-05-29 08:43:31       Running     False  Philadelphia Running     10.15
# 2020-05-28 07:39:57       Running     False  Philadelphia Running      7.90
# 2020-05-27 08:12:33       Running     False  Philadelphia Running      8.01
# 2020-05-26 06:45:42       Running     False  Philadelphia Running      7.20
# 2020-05-25 08:02:30       Running     False  Philadelphia Running      7.28
#
#                     calories      time  avg_hr  max_hr  avg_run_cadence  \
# date
# 2020-05-29 08:43:31      649  01:29:10     146     180              192
# 2020-05-28 07:39:57      592  01:04:58     150     198              196
# 2020-05-27 08:12:33      584  01:06:32     148     164              196
# 2020-05-26 06:45:42      537  01:00:14     149     167              188
# 2020-05-25 08:02:30      513  01:00:11     148     161              194
#
#                      max_run_cadence  ... bottom_time min_temp  \
# date                                  ...
# 2020-05-29 08:43:31              236  ...        0:00      0.0
# 2020-05-28 07:39:57              202  ...        0:00      0.0
# 2020-05-27 08:12:33              204  ...        0:00      0.0
# 2020-05-26 06:45:42              200  ...        0:00      0.0
# 2020-05-25 08:02:30              202  ...        0:00      0.0
#
#                     surface_interval decompression  best_lap_time  \
# date
# 2020-05-29 08:43:31             0:00            No       01:25.39
# 2020-05-28 07:39:57             0:00            No       07:26.88
# 2020-05-27 08:12:33             0:00            No       00:03.14
# 2020-05-26 06:45:42             0:00            No       01:49.06
# 2020-05-25 08:02:30             0:00            No       02:41.30
#
#                      number_of_laps  max_temp  athlete_id  filetype  is_race
# date
# 2020-05-29 08:43:31              11       0.0           2    garmin        0
# 2020-05-28 07:39:57               8       0.0           2    garmin        0
# 2020-05-27 08:12:33               9       0.0           2    garmin        0
# 2020-05-26 06:45:42               8       0.0           2    garmin        0
# 2020-05-25 08:02:30               8       0.0           2    garmin        0
#
# [5 rows x 31 columns]

# %%
#https://stackoverflow.com/questions/21269399/datetime-dtypes-in-pandas-read-csv#:~:text=There%20is%20no%20datetime%20dtype,end%20up%20with%20a%20string.
#Very interesting. I will have to make columns a datetime after I import them!

# %%
import re

# %%
test_str = '2020-05-29'

# %%
match = re.match("\d+-\d\d-?\d\d", test_str)

# %%
match[0]
# Out:
# '2020-05-29'

# %%
test_2 = '2020-05-29 07:15:35'

# %%
type(test.index.to_series().astype('str'))
# Out:
# pandas.core.series.Series

# %%
time_of_day = [re.findall("\d\d:\d\d:\d\d", test.index.to_series().astype('str')[i])[0] for i in range(len(test))]

# %%
test['time_of_day'] = time_of_day
test['time_of_day'][:3]
# Out:
# date
# 2020-05-29    08:43:31
# 2020-05-28    07:39:57
# 2020-05-27    08:12:33
# Name: time_of_day, dtype: object

# %%
test['time_of_day'] = pd.to_timedelta(test['time_of_day'])

# %%
type(test.index)
# Out:
# pandas.core.indexes.base.Index

# %%
test.index = pd.DatetimeIndex(test.index).normalize()

# %%
test.head(20)
# Out:
#                 activity_type  favorite                 title  distance  \
# date
# 2020-05-29            Running     False  Philadelphia Running     10.15
# 2020-05-28            Running     False  Philadelphia Running      7.90
# 2020-05-27            Running     False  Philadelphia Running      8.01
# 2020-05-26            Running     False  Philadelphia Running      7.20
# 2020-05-25            Running     False  Philadelphia Running      7.28
# 2020-05-24            Running     False  Philadelphia Running      7.03
# 2020-05-23            Running     False  Philadelphia Running     12.58
# 2020-05-22            Running     False  Philadelphia Running      5.95
# 2020-05-21            Running     False  Philadelphia Running     10.20
# 2020-05-18  Treadmill Running     False     Treadmill Running      0.01
# 2020-05-18  Treadmill Running     False     Treadmill Running      6.26
# 2020-05-17            Running     False  Philadelphia Running      9.00
# 2020-05-16            Running     False  Philadelphia Running     10.31
# 2020-05-15            Running     False  Philadelphia Running      7.98
# 2020-05-14            Running     False  Philadelphia Running      8.27
# 2020-05-13            Running     False  Philadelphia Running      8.02
# 2020-05-12            Running     False  Philadelphia Running      7.25
# 2020-05-11            Running     False  Philadelphia Running      6.00
# 2020-05-09            Running     False  Philadelphia Running     50.01
# 2020-05-07            Running     False  Philadelphia Running      3.56
#
#            calories        time  avg_hr  max_hr  avg_run_cadence  \
# date
# 2020-05-29      649    01:29:10     146     180              192
# 2020-05-28      592    01:04:58     150     198              196
# 2020-05-27      584    01:06:32     148     164              196
# 2020-05-26      537    01:00:14     149     167              188
# 2020-05-25      513    01:00:11     148     161              194
# 2020-05-24      582    00:58:40     160     202              194
# 2020-05-23      920    01:47:38     149     179              192
# 2020-05-22      424    00:49:00     150     168              192
# 2020-05-21      866    01:28:31     163     200              196
# 2020-05-18        3  00:00:46.8     100     123              160
# 2020-05-18      481    01:02:37     141     174              178
# 2020-05-17      815    01:20:47     166     202              196
# 2020-05-16      508    01:31:28     125     147              192
# 2020-05-15      459    01:11:46     133     161              192
# 2020-05-14      362    01:16:06     117     144              190
# 2020-05-13      377    01:11:55     120     126              194
# 2020-05-12      355    01:09:06     119     139              188
# 2020-05-11      308    00:57:58     121     144              188
# 2020-05-09    4,299    08:24:38     169     205              186
# 2020-05-07      208    00:28:42     131     149              198
#
#             max_run_cadence  ... min_temp surface_interval decompression  \
# date                         ...
# 2020-05-29              236  ...      0.0             0:00            No
# 2020-05-28              202  ...      0.0             0:00            No
# 2020-05-27              204  ...      0.0             0:00            No
# 2020-05-26              200  ...      0.0             0:00            No
# 2020-05-25              202  ...      0.0             0:00            No
# 2020-05-24              200  ...      0.0             0:00            No
# 2020-05-23              200  ...      0.0             0:00            No
# 2020-05-22              202  ...      0.0             0:00            No
# 2020-05-21              204  ...      0.0             0:00            No
# 2020-05-18              182  ...      0.0             0:00            No
# 2020-05-18              236  ...      0.0             0:00            No
# 2020-05-17              202  ...      0.0             0:00            No
# 2020-05-16              202  ...      0.0             0:00            No
# 2020-05-15              200  ...      0.0             0:00            No
# 2020-05-14              200  ...      0.0             0:00            No
# 2020-05-13              202  ...      0.0             0:00            No
# 2020-05-12              198  ...      0.0             0:00            No
# 2020-05-11              198  ...      0.0             0:00            No
# 2020-05-09              234  ...      0.0             0:00            No
# 2020-05-07              214  ...      0.0             0:00            No
#
#            best_lap_time  number_of_laps  max_temp  athlete_id  filetype  \
# date
# 2020-05-29      01:25.39              11       0.0           2    garmin
# 2020-05-28      07:26.88               8       0.0           2    garmin
# 2020-05-27      00:03.14               9       0.0           2    garmin
# 2020-05-26      01:49.06               8       0.0           2    garmin
# 2020-05-25      02:41.30               8       0.0           2    garmin
# 2020-05-24      04:00.73               4       0.0           2    garmin
# 2020-05-23      00:39.54              13       0.0           2    garmin
# 2020-05-22      07:42.03               6       0.0           2    garmin
# 2020-05-21      01:53.69              11       0.0           2    garmin
# 2020-05-18      00:00.00               1       0.0           2    garmin
# 2020-05-18      02:25.58               7       0.0           2    garmin
# 2020-05-17      04:15.43               6       0.0           2    garmin
# 2020-05-16      03:02.88              11       0.0           2    garmin
# 2020-05-15      08:37.90               8       0.0           2    garmin
# 2020-05-14      03:00.27               9       0.0           2    garmin
# 2020-05-13      00:13.50               9       0.0           2    garmin
# 2020-05-12      02:39.56               8       0.0           2    garmin
# 2020-05-11      00:01.89               7       0.0           2    garmin
# 2020-05-09      00:03.27              51       0.0           2    garmin
# 2020-05-07      04:39.97               4       0.0           2    garmin
#
#             is_race     time_of_day
# date
# 2020-05-29        0 0 days 08:43:31
# 2020-05-28        0 0 days 07:39:57
# 2020-05-27        0 0 days 08:12:33
# 2020-05-26        0 0 days 06:45:42
# 2020-05-25        0 0 days 08:02:30
# 2020-05-24        0 0 days 08:33:30
# 2020-05-23        0 0 days 10:03:16
# 2020-05-22        0 0 days 17:06:03
# 2020-05-21        0 0 days 07:38:53
# 2020-05-18        0 0 days 17:52:45
# 2020-05-18        0 0 days 06:36:54
# 2020-05-17        0 0 days 08:18:27
# 2020-05-16        0 0 days 08:58:40
# 2020-05-15        0 0 days 07:33:08
# 2020-05-14        0 0 days 08:02:24
# 2020-05-13        0 0 days 07:37:02
# 2020-05-12        0 0 days 07:16:59
# 2020-05-11        0 0 days 08:33:42
# 2020-05-09        0 0 days 06:40:53
# 2020-05-07        0 0 days 07:52:17
#
# [20 rows x 32 columns]

# %%
test['athlete_id'][0]
# Out:
# 2

# %%
race_dates = ['2020-05-09']

# %%
#pull out the test dates
test[test.index.isin(race_dates)]['is_race']
# Out:
# date
# 2020-05-09    0
# Name: is_race, dtype: int64

# %%
test['is_race'] = np.where(test.index.isin(race_dates), 1, 0)

# %%
test[test.index.isin(race_dates)]['is_race']
# Out:
# date
# 2020-05-09    1
# Name: is_race, dtype: int64

# %%
test_athlete_dict = {2:{'race_date_list':['2020-05-09'],
                          'age':35, 'gender':'F', 
                          'race_count':1, 
                          'training_elevation':1000, 
                          'max_hr':175}, 
                     3:{'race_date_list':['2018-05-05','2018-06-10', '2018-09-02', '2019-10-13', '2019-07-27', '2019-06-09'], 
                          'age':33, 'gender':'M', 
                          'race_count':2, 
                          'training_elevation':5280, 
                          'max_hr':185}
                    }

# %%
test_athlete_dict[3]['race_date_list']
# Out:
# ['2018-06-09', '2018-09-02', '2019-10-13', '2019-07-27', '2019-06-09']

# %%
from datetime import datetime, timedelta

# %%
month = timedelta(31)

# %%
pd.to_datetime(test_athlete_dict[3]['race_date_list'][0])-month*3
# Out:
# Timestamp('2018-03-08 00:00:00')

# %%
test.index = pd.DatetimeIndex(test.index).normalize()
test.index
# Out:
# DatetimeIndex(['2020-05-29', '2020-05-28', '2020-05-27', '2020-05-26',
#                '2020-05-25', '2020-05-24', '2020-05-23', '2020-05-22',
#                '2020-05-21', '2020-05-18', '2020-05-18', '2020-05-17',
#                '2020-05-16', '2020-05-15', '2020-05-14', '2020-05-13',
#                '2020-05-12', '2020-05-11', '2020-05-09', '2020-05-07',
#                '2020-05-06', '2020-05-05', '2020-05-04', '2020-05-03',
#                '2020-05-02', '2020-05-01', '2020-04-29', '2020-04-28',
#                '2020-04-27', '2020-04-26', '2020-04-26', '2020-04-25',
#                '2020-04-23', '2020-04-22', '2020-04-21', '2020-04-19',
#                '2020-04-18', '2020-04-17', '2020-04-16', '2020-04-15',
#                '2020-04-14', '2020-04-13', '2020-04-12', '2020-04-11',
#                '2020-04-10', '2020-04-10', '2020-04-08', '2020-04-07',
#                '2020-04-06', '2020-04-06'],
#               dtype='datetime64[ns]', name='date', freq=None)

# %%
date_1 = pd.to_datetime('2020-05-05')

# %%
test[date_1:(date_1-month)]
# Out:
#            activity_type  favorite                 title  distance calories  \
# date
# 2020-05-05       Running     False  Philadelphia Running      7.10      722
# 2020-05-04       Running     False  Philadelphia Running      7.04      551
# 2020-05-03       Running     False  Philadelphia Running     10.05      818
# 2020-05-02       Running     False  Philadelphia Running      7.11      449
# 2020-05-01       Running     False  Philadelphia Running     14.85      803
# 2020-04-29       Running     False  Philadelphia Running      8.00      663
# 2020-04-28       Running     False  Philadelphia Running      7.98      567
# 2020-04-27       Running     False  Philadelphia Running      7.99      814
# 2020-04-26       Running     False  Philadelphia Running      1.64      344
# 2020-04-26       Running     False  Philadelphia Running      0.06       14
# 2020-04-25       Running     False  Philadelphia Running     15.24      745
# 2020-04-23       Running     False  Philadelphia Running      8.08      660
# 2020-04-22       Running     False  Philadelphia Running      8.00      617
# 2020-04-21       Running     False  Philadelphia Running      8.02      643
# 2020-04-19       Running     False  Philadelphia Running      8.36      433
# 2020-04-18       Running     False  Philadelphia Running      8.00      546
# 2020-04-17       Running     False  Philadelphia Running     16.01    1,173
# 2020-04-16       Running     False  Philadelphia Running      7.94      678
# 2020-04-15       Running     False  Philadelphia Running      7.71      475
# 2020-04-14       Running     False  Philadelphia Running      8.10      480
# 2020-04-13       Running     False  Philadelphia Running      6.51      398
# 2020-04-12       Running     False  Philadelphia Running      8.56      828
# 2020-04-11       Running     False  Philadelphia Running      2.50      397
# 2020-04-10       Running     False  Philadelphia Running     21.61    1,457
# 2020-04-10       Running     False  Philadelphia Running      9.19      926
# 2020-04-08       Running     False  Philadelphia Running     10.10      938
# 2020-04-07       Running     False  Philadelphia Running      4.79      594
# 2020-04-06       Running     False  Philadelphia Running      4.02      484
# 2020-04-06       Running     False  Philadelphia Running      6.84      467
#
#                   time  avg_hr  max_hr  avg_run_cadence  max_run_cadence  ...  \
# date                                                                      ...
# 2020-05-05    01:00:18     188     210              194              202  ...
# 2020-05-04    01:01:22     154     200              196              204  ...
# 2020-05-03    01:31:30     152     155              188              202  ...
# 2020-05-02    01:01:51     135     170              194              204  ...
# 2020-05-01    02:12:45     140     161              194              212  ...
# 2020-04-29    01:05:57     170     203              196              206  ...
# 2020-04-28    01:07:02     152     190              196              202  ...
# 2020-04-27    01:07:44     189     195              196              212  ...
# 2020-04-26    00:41:32     150     190              148              212  ...
# 2020-04-26  00:01:47.1     134     140              118              118  ...
# 2020-04-25    02:13:51     137     164              192              212  ...
# 2020-04-23    01:12:25     154     176              192              212  ...
# 2020-04-22    01:09:45     150     172              198              204  ...
# 2020-04-21    01:08:59     154     184              200              208  ...
# 2020-04-19    01:31:41      64      85              118              184  ...
# 2020-04-18    01:10:51     140     160              196              206  ...
# 2020-04-17    02:20:15     155     197              196              236  ...
# 2020-04-16    01:11:34     158     183              196              204  ...
# 2020-04-15    01:05:40     137     143              196              204  ...
# 2020-04-14    01:09:55     142     163              196              206  ...
# 2020-04-13    01:00:08     140     168              192              202  ...
# 2020-04-12    01:24:08     185     202              188              206  ...
# 2020-04-11    01:05:55     140     177              120              204  ...
# 2020-04-10    03:35:07     165     206              188              198  ...
# 2020-04-10    01:25:47     185     204              192              200  ...
# 2020-04-08    01:28:06     182     211              196              204  ...
# 2020-04-07    00:55:02     182     206              200              210  ...
# 2020-04-06    01:17:04     133     210              164              236  ...
# 2020-04-06    01:02:12     148     192              198              206  ...
#
#            bottom_time min_temp surface_interval decompression  best_lap_time  \
# date
# 2020-05-05        0:00      0.0             0:00            No       01:01.35
# 2020-05-04        0:00      0.0             0:00            No       00:27.69
# 2020-05-03        0:00      0.0             0:00            No       00:28.55
# 2020-05-02        0:00      0.0             0:00            No       01:16.38
# 2020-05-01        0:00      0.0             0:00            No       07:45.87
# 2020-04-29        0:00      0.0             0:00            No       00:02.61
# 2020-04-28        0:00      0.0             0:00            No       07:47.81
# 2020-04-27        0:00      0.0             0:00            No       07:35.15
# 2020-04-26        0:00      0.0             0:00            No       19:10.25
# 2020-04-26        0:00      0.0             0:00            No       00:00.00
# 2020-04-25        0:00      0.0             0:00            No       02:03.75
# 2020-04-23        0:00      0.0             0:00            No       01:08.44
# 2020-04-22        0:00      0.0             0:00            No       08:10.16
# 2020-04-21        0:00      0.0             0:00            No       00:18.89
# 2020-04-19        0:00      0.0             0:00            No       04:29.15
# 2020-04-18        0:00      0.0             0:00            No       08:28.13
# 2020-04-17        0:00      0.0             0:00            No       00:02.50
# 2020-04-16        0:00      0.0             0:00            No       08:15.13
# 2020-04-15        0:00      0.0             0:00            No       05:50.33
# 2020-04-14        0:00      0.0             0:00            No       00:53.91
# 2020-04-13        0:00      0.0             0:00            No       05:09.82
# 2020-04-12        0:00      0.0             0:00            No       08:40.38
# 2020-04-11        0:00      0.0             0:00            No       10:43.96
# 2020-04-10        0:00      0.0             0:00            No       05:50.45
# 2020-04-10        0:00      0.0             0:00            No       02:49.48
# 2020-04-08        0:00      0.0             0:00            No       00:51.82
# 2020-04-07        0:00      0.0             0:00            No      06:16.100
# 2020-04-06        0:00      0.0             0:00            No       00:04.20
# 2020-04-06        0:00      0.0             0:00            No       07:36.27
#
#             number_of_laps  max_temp  athlete_id  filetype  is_race
# date
# 2020-05-05               8       0.0           2    garmin        0
# 2020-05-04               8       0.0           2    garmin        0
# 2020-05-03              11       0.0           2    garmin        0
# 2020-05-02               8       0.0           2    garmin        0
# 2020-05-01              15       0.0           2    garmin        0
# 2020-04-29               9       0.0           2    garmin        0
# 2020-04-28               8       0.0           2    garmin        0
# 2020-04-27               8       0.0           2    garmin        0
# 2020-04-26               2       0.0           2    garmin        0
# 2020-04-26               1       0.0           2    garmin        0
# 2020-04-25              16       0.0           2    garmin        0
# 2020-04-23               9       0.0           2    garmin        0
# 2020-04-22               8       0.0           2    garmin        0
# 2020-04-21               9       0.0           2    garmin        0
# 2020-04-19               9       0.0           2    garmin        0
# 2020-04-18               8       0.0           2    garmin        0
# 2020-04-17              17       0.0           2    garmin        0
# 2020-04-16               8       0.0           2    garmin        0
# 2020-04-15               8       0.0           2    garmin        0
# 2020-04-14               9       0.0           2    garmin        0
# 2020-04-13               7       0.0           2    garmin        0
# 2020-04-12               9       0.0           2    garmin        0
# 2020-04-11               3       0.0           2    garmin        0
# 2020-04-10              22       0.0           2    garmin        0
# 2020-04-10              10       0.0           2    garmin        0
# 2020-04-08              11       0.0           2    garmin        0
# 2020-04-07               5       0.0           2    garmin        0
# 2020-04-06               5       0.0           2    garmin        0
# 2020-04-06               7       0.0           2    garmin        0
#
# [29 rows x 31 columns]

# %%
def set_up_for_prediction(df_filepath, athlete_dict):
    
    '''
    Inputs: csv filepath, and athlete dictionary
    -Dictionary contains an entry for race date, keyed to athlete id
    Outputs: 
        1) a csv with races indicated, indexed by time series
        2) a csv with summary values for 1 week, 2 weeks, 1 month, 2 months, 3 months
            - If values are not available, they will be 0s
    '''
    #Read in the csv:
    working = pd.read_csv(df_filepath, index_col='date').drop('date.1', axis =1)
    
    athlete_id = working['athlete_id'][0]
    
    #get the race dates for the selected athlete:
    race_dates = athlete_dict[athlete_id]['race_date_list']
    
    #Set the index as a datetime:
    working.index = pd.to_datetime(working.index)
    
    #Create a month interval: (we can multiply by 3 to get the 3 month values)
    month = timedelta(31)
    day = timedelta(1)
    
    #Create a time of day column:
    time_of_day = [re.findall("\d\d:\d\d:\d\d", working.index.to_series().astype('str')[i])[0] for i in range(len(working))]
    
    #Drop the hours and minutes and seconds:
    working.index = pd.DatetimeIndex(working.index).normalize()
    
    #Label all of the races:
    working['is_race'] = np.where(working.index.isin(race_dates), 1, 0)
    
    #select the last month and last 3 months of data from the working file, and export them as separate csvs to the 'races' folder:
    
    for i in range(len(race_dates)):
        #i is the counter, find the 1 month and 3 month data:
        rd = pd.to_datetime(race_dates[i])
        race_1_mo_back = working[rd+day:rd-month]
        race_1_mo_back.sort_index(inplace=True)
        race_1_mo_back.to_csv(f'./data/races/athlete_{athlete_id}_race_{i}_1_mo.csv')
        try:
            #This way if there is not 3 months data, it just skips out.
            race_3_mo_back = working[rd+day:(rd-month*3)]
            race_3_mo_back.sort_index(inplace=True)
            race_3_mo_back.to_csv(f'./data/races/athlete_{athlete_id}_race_{i}_3_mo.csv')
        except:
            pass

# %%
test_athlete_dict[3]['race_date_list']
# Out:
# ['2018-06-09', '2018-10-02']

# %%
import_transf_garmin('./data/raw/Garmin/Keith_Activities_2018-Present.csv', 3, test_athlete_dict[3]['race_date_list'])

# %%
set_up_for_prediction('./data/clean/garmin_clean/clean_3.csv', test_athlete_dict)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#Alright  I have a data pipeline that will spit out all my races with 1 month and 3 month histories.
#Going to write a clean notebook for it.

# %%
n = 2
with open('./data/athletes.json') as json_file: 
    data = json.load(json_file)
    print(data[str(n)]['race_date_list'])
type(data)
# Out:
# ['2020-05-09']
# dict

# %%
def add_to_athletes(race_list, age, gender, trng_elev, max_hr):
    with open('./data/athletes.json') as json_file: 
        data = json.load(json_file)
        print(len(data))
        athlete_stats = {
            "race_date_list":race_list,
            "age":age,
            "race_count":len(race_list),
            "training_elevation":trng_elev,
            "max_hr":max_hr
        }
        data.append(
        {str(len(data)+1):athlete_stats}
        )
    with open('./data/athletes.json', "w") as output:  
        json.dump(data, output)

# %%
riggs = pd.read_csv('./data/raw/Garmin/Riggs Activities r4 w favorites.csv')

# %%
riggs['Max HR'].replace('--', 0, inplace=True);
riggs['Avg HR'].replace('--', 0, inplace=True);

# %%
pd.to_numeric(riggs['Max HR']).max()
# Out:
# 247

# %%
pd.to_numeric(riggs['Avg HR']).max()
# Out:
# 183

# %%
riggs[pd.to_numeric(riggs['Max HR'])  >195]
# Out:
#           Activity Type                 Date  Favorite  \
# 269             Running  2020-06-13 11:34:51     False
# 301      Indoor Cycling  2020-05-27 18:01:07     False
# 350      Indoor Cycling  2020-04-15 16:12:21     False
# 353   Treadmill Running  2020-04-12 08:30:33     False
# 366   Treadmill Running  2020-04-01 18:53:49     False
# 1220     Indoor Cycling  2017-08-29 05:26:40     False
# 1360     Indoor Cycling  2017-04-05 05:54:22     False
#
#                              Title Distance Calories      Time Avg HR Max HR  \
# 269                Boulder Running     6.21      854  00:48:21    183    202
# 301     West Vidette - TrainerRoad    14.56      506  00:45:00    123    239
# 350           Baxter - TrainerRoad    27.27      998  01:30:00    116    213
# 353              Treadmill Running    11.86    1,299  01:36:41    155    196
# 366              Treadmill Running     2.25      270  00:25:59    152    247
# 1220  FTP Test 8 - 313W (298W FTP)     0.00      781  01:00:04    161    197
# 1360                Indoor Cycling     0.00      804  01:16:24    150    196
#
#      Aerobic TE  ... Total Reps Total Sets Climb Time Bottom Time Min Temp  \
# 269         5.0  ...         --         --      48:21        0:00     78.8
# 301          --  ...         --         --      45:00        0:00      0.0
# 350          --  ...         --         --    1:30:00        0:00      0.0
# 353         3.8  ...         --         --    1:36:41        0:00     64.4
# 366         2.4  ...         --         --      25:59        0:00     71.6
# 1220        4.8  ...         --         --    1:00:04        0:00     71.6
# 1360        3.8  ...         --         --    1:16:24        0:00     59.0
#
#      Surface Interval  Decompression  Best Lap Time  Number of Laps Max Temp
# 269              0:00             No       01:37.49               7      0.0
# 301              0:00             No       01:00.00              17      0.0
# 350              0:00             No       01:00.00              38      0.0
# 353              0:00             No       09:13.96               6      0.0
# 366              0:00             No       10:59.54               2      0.0
# 1220             0:00             No       00:00.00              --      0.0
# 1360             0:00             No       00:00.00              --      0.0
#
# [7 rows x 44 columns]
